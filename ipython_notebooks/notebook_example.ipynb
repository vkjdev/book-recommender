# %%
#### THIS IS IPYTHON NOTEBOOK
- run cells with Shift + Enter
- enter cell above with A
- enter cell below by B
- remove cell by DD

# %%
import numpy as np
import pandas as pd
from recommender import Dummy
# %matplotlib inline

# %%
def random_float():  
    return np.random.rand()
random_float()
# Out:
# 0.4878795963123882

# %%
example_df = pd.DataFrame([random_float() for x in xrange(100)])

# %%
example_df.plot()

# %%
dummy=Dummy()
dummy.dummy_method()
# Out:
# True
